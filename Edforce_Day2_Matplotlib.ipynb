# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([0,10])
y=np.array([5,25])
plt.plot(x,y,'+--r')

# %%
x=np.array([0,10])
y=np.array([5,25])
plt.title("Random data",loc='left')
plt.xlabel("x_t")
plt.ylabel("vggh")
plt.grid()
plt.plot(x,y,marker='o',ms=20,mfc='b',mec='r')

# %%
x=np.array([0,1,2,3])
y=np.array([5,10,15,20])
plt.subplot(1,2,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
x=np.array([0,1,2,3])
y=np.array([5,10,15,20])
plt.subplot(2,3,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([5,10,15,20])
plt.subplot(2,3,3)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,4)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([5,10,15,20])
plt.subplot(2,3,5)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,6)
plt.plot(x,y)

# %%
y1=np.array([0,1,2,3])
x1=np.array([1,5,8,6])
y2=np.array([2,4,6,8])
x2=np.array([1,2,7,5])
plt.plot(x1,y1)
plt.plot(x2,y2)

# %%
x=np.array(["A","B","C"])
y=np.array([10,20,15])
plt.barh(x,y,color="hotpink")
# Out:
# <BarContainer object of 3 artists>

# %%
y=np.array([13,16,28,35])
labels=["A","B","C","D"]
color=["black","hotpink","blue","green"]
plt.pie(y,labels=labels,colors=color)
# Out:
# ([<matplotlib.patches.Wedge at 0x2476bafcc10>,
#   <matplotlib.patches.Wedge at 0x2476bb0c130>,
#   <matplotlib.patches.Wedge at 0x2476bb0c610>,
#   <matplotlib.patches.Wedge at 0x2476bb0caf0>],
#  [Text(0.9933822113264107, 0.472431775201722, 'A'),
#   Text(0.14978332953220358, 1.0897545385059186, 'B'),
#   Text(-1.0769924864291622, 0.22380166258348252, 'C'),
#   Text(0.40353954905111317, -1.0233063238110203, 'D')])
